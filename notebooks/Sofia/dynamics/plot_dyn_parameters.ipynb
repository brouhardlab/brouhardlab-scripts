# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import csv
import pandas as pd
from pandas.api.types import CategoricalDtype
import scipy as sp
from pathlib import Path
import tkinter as tk
from tkinter import filedialog
import itertools
from colour import Color
from datetime import date

# %%
askmastersheet = filedialog.askopenfilename() # show an "Open" dialog box and return the path to the selected file
data = pd.read_csv(askmastersheet,header=[0,1], encoding='utf-8')
data
# Out:
#   Growth Rate $(\mu m / min)$               [Tubulin] $(\mu M)$ DCX Type  \
#                          Mean Coefficient 1 [Tubulin] $(\mu M)$ DCX Type
# 0                    0.322131      0.053473                   6       WT
# 1                    0.008361      0.006841                   6       WT
# 2                    1.134980      0.145150                   6       WT
# 3                    0.013839      0.011371                   6       WT
# 4                    0.223938      0.041353                   6       WT
# 5                    0.001400      0.001238                   6       WT
# 6                    0.913734      0.208520                   6       WT
# 7                    0.025771      0.021081                   6       WT
#
#   [DCX] $(n M)$ [EB] $(n M)$ Time to Nucleate $(min)$ Lifetime $(min)$  \
#   [DCX] $(n M)$ [EB] $(n M)$                     Mean    Coefficient 0
# 0             0            0                12.312598        12.282308
# 1             0            0                 4.538324         1.895647
# 2             0           20                12.230672         1.525851
# 3             0           20                 2.494147         0.272675
# 4            60            0                 4.563966        19.528246
# 5            60            0                 0.835463         7.619622
# 6            60           20                23.986178         1.881294
# 7            60           20                 5.606422         0.306725
#
#                            Shrink Rate $(\mu m / min)$
#   Coefficient 1       Mean                        Mean Coefficient 1
# 0      0.162580   1.996857                    4.581672      1.333351
# 1      0.028505   0.658303                    0.384949      0.314322
# 2      1.046556   1.596888                   11.156076      1.959390
# 3      0.170070   0.544870                    0.558084      0.462876
# 4      1.044977  20.406574                    1.182502      0.200999
# 5      0.419941  16.163048                    0.008545      0.006977
# 6      0.547440   1.029896                    4.015542      1.393842
# 7      0.112861   0.380238                    0.159840      0.130603

# %%
data['Value Type']=np.where(data.index%2==0, 'Value', 'SE') 
data
# Out:
#   Growth Rate $(\mu m / min)$               [Tubulin] $(\mu M)$  \
#                          Mean Coefficient 1  Unnamed: 2_level_1
# 0                    0.322131      0.053473                   6
# 1                    0.008361      0.006841                   6
# 2                    1.134980      0.145150                   6
# 3                    0.013839      0.011371                   6
# 4                    0.223938      0.041353                   6
# 5                    0.001400      0.001238                   6
# 6                    0.913734      0.208520                   6
# 7                    0.025771      0.021081                   6
#
#             DCX Type      [DCX] $(n M)$       [EB] $(n M)$  \
#   Unnamed: 3_level_1 Unnamed: 4_level_1 Unnamed: 5_level_1
# 0                 WT                  0                  0
# 1                 WT                  0                  0
# 2                 WT                  0                 20
# 3                 WT                  0                 20
# 4                 WT                 60                  0
# 5                 WT                 60                  0
# 6                 WT                 60                 20
# 7                 WT                 60                 20
#
#   Time to Nucleate $(min)$ Lifetime $(min)$                           \
#                       Mean    Coefficient 0 Coefficient 1       Mean
# 0                12.312598        12.282308      0.162580   1.996857
# 1                 4.538324         1.895647      0.028505   0.658303
# 2                12.230672         1.525851      1.046556   1.596888
# 3                 2.494147         0.272675      0.170070   0.544870
# 4                 4.563966        19.528246      1.044977  20.406574
# 5                 0.835463         7.619622      0.419941  16.163048
# 6                23.986178         1.881294      0.547440   1.029896
# 7                 5.606422         0.306725      0.112861   0.380238
#
#   Shrink Rate $(\mu m / min)$               Value Type
#                          Mean Coefficient 1
# 0                    4.581672      1.333351      Value
# 1                    0.384949      0.314322         SE
# 2                   11.156076      1.959390      Value
# 3                    0.558084      0.462876         SE
# 4                    1.182502      0.200999      Value
# 5                    0.008545      0.006977         SE
# 6                    4.015542      1.393842      Value
# 7                    0.159840      0.130603         SE
